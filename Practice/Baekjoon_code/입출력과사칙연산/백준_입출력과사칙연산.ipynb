# %%
#@title 기본 제목 텍스트
#2557
print("Hello World!")
# Out:
# Hello World!

# %%
#10718
str='강한친구 대한육군'
print(str)
print(str)
# Out:
# 강한친구 대한육군
# 강한친구 대한육군

# %%
#10171
print('\\    /\\')
print(" )  ( ')")
print('(  /  )')
print(' \\(__)|')
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|

# %%
#10172 아래 예제와 같이 개를 출력하시오.
print("|\_/|")
print("|q p|   /}")
print('( 0 )"""\\')
print('|"^"`    |')
print("||_/=\\\__|")
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|

# %%
#1000
a, b = map(int, input().split(' '))
if a>0 and b<10:
  print(a+b)
else:
  print("a,b의 조건에 부합하지 않습니다.")
# Out:
# 1,3
# 4

# %%
#1001
a, b = map(int, input().split(' '))
if a>0 and b<10 :
    if a>b:
        print(a-b)
    else:
        print(b-a)
else:
    print("a,b의 조건에 부합하지 않습니다.")
# Out:
# 2 8
# 6

# %%
#10998
a, b = map(int, input().split(' '))
if a>0 and b<10 :
  output=a*b
  print(output)
else:
  print("a,b의 조건에 부합하지 않습니다")
# Out:
# 3 4
# 12

# %%
#1008
a, b = map(int, input().split(' '))
if a>0 and b<10 : 
  output = a/b
  print(output)

else : 
  print("a,b의 조건에 부합하지 않습니다")
# Out:
# 4 5
# 0.8

# %%
#10869
a, b = map(int, input().split(' '))

if a>=1 and b<=10000 : 
  if a>b :
    addition=a+b 
    subtraction=a-b
    multiplication=a*b
    quotient=int(a/b)
    remainder=a%b
    print(addition,"\n" ,subtraction,"\n" ,multiplication,"\n",quotient,"\n",remainder,sep='')
  
  else:
    addition=b+a
    subtraction=b-a
    multiplication=b*a
    quotient=int(a/b)
    remainder=b%a
    print(addition,"\n" ,subtraction,"\n" ,multiplication,"\n",quotient,"\n",remainder,sep='')

else:
 print("a,b의 조건에 부합하지 않습니다")
# Out:
# 7 3
# 10
# 4
# 21
# 2
# 1

# %%
#10430
e, f, g =  map(int, input().split(' '))
if e >= 2 and f >= 2 and g >= 2 :
  if e <= 10000 and f <= 10000 and g <= 10000:
    a=(e+f)%g
    b=((e%g)+(f%g))%g
    c=(e*f)%g
    d=((e%g)*(f%g))%g
    print(a,"\n",b,"\n",c,"\n",d,sep='')
  else : 
    print("조건에 부합하지 않습니다")
else : 
  print("조건에 부합하지 않습니다")
# Out:
# 2 2 10001
# 조건에 부합하지 않습니다

# %%
#2588
a = int(input())
b = int(input())
if a>=100 and b>=100 :
  c=a*int(b%10)
  d=a*int(int(b%100)/10)
  e=a*int(b/100)
  f=a*b
  print(c,d,e,f,sep='\n')

#참고
#c=a*(b%10)
#d=a*((b%100)//10)
#e=a*(b//100)
# Out:
# 582
# 246
# 3492
# 2328
# 1164
# 143172
